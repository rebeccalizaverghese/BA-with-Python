# %% [markdown]
# <a href="https://colab.research.google.com/github/rebeccalizaverghese/BA-with-Python/blob/main/13_6_df_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Supermarket_sales.csv")

# %%
df
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel      86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
df.tail()
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax      Total       Date  \
# 995    Health and beauty      40.35         1   2.0175    42.3675  1/29/2019
# 996   Home and lifestyle      97.38        10  48.6900  1022.4900   3/2/2019
# 997   Food and beverages      31.84         1   1.5920    33.4320   2/9/2019
# 998   Home and lifestyle      65.82         1   3.2910    69.1110  2/22/2019
# 999  Fashion accessories      88.34         7  30.9190   649.2990  2/18/2019
#
#       Time  Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
df.loc[0, "City"]
# Out:
# 'Yangon'

# %%
df.loc[3, "Gender"]
# Out:
# 'Male'

# %%
df.loc[500, "City"]
# Out:
# 'Mandalay'

# %%
df.loc[999, "Productline"]
# Out:
# 'Fashion accessories'

# %%
df.loc[648, "Payment"]
# Out:
# 'Cash'

# %%
new_data=[]
for x in df.index:
  new_data.append(df.loc[x, "City"])
new_data
# Out:
# ['Yangon',
#  'Naypyitaw',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Naypyitaw',
#  'Yangon',
#  'Naypyitaw',
#  'Yangon',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Mandalay',
#  'Naypyitaw',
#  'Mandalay',
#  'Mandalay',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Yangon',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Yangon',
#  'Yangon',
#  'Naypyitaw',
#  'Mandalay',
#  'Mandalay',
#  'Naypyitaw',
#  'Mandalay',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Yangon',
#  'Mandalay',
#  'Naypyitaw',
#  'Mandalay',
#  'Naypyitaw',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Mandalay',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Naypyitaw',
#  'Mandalay',
#  'Yangon',
# ...

# %%
for x in range (500):
  new_data.append(df.loc[x, "City"])
new_data
# Out:
# ['Yangon',
#  'Naypyitaw',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Naypyitaw',
#  'Yangon',
#  'Naypyitaw',
#  'Yangon',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Mandalay',
#  'Naypyitaw',
#  'Mandalay',
#  'Mandalay',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Yangon',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Yangon',
#  'Yangon',
#  'Naypyitaw',
#  'Mandalay',
#  'Mandalay',
#  'Naypyitaw',
#  'Mandalay',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Mandalay',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Yangon',
#  'Mandalay',
#  'Naypyitaw',
#  'Mandalay',
#  'Naypyitaw',
#  'Yangon',
#  'Yangon',
#  'Yangon',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Naypyitaw',
#  'Mandalay',
#  'Yangon',
#  'Mandalay',
#  'Yangon',
#  'Naypyitaw',
#  'Mandalay',
#  'Yangon',
# ...

# %%
df.plot(figsize=(15,10))

# %%
df.plot()

# %%
df.Unitprice.plot()

# %%
df.Quantity.plot()

# %%
df.Payment.hist()

# %%
df.City.hist()

# %%
df.Gender.hist()

# %%
import matplotlib.pyplot as plt
plt.hist(df["Tax"])
plt.show()
